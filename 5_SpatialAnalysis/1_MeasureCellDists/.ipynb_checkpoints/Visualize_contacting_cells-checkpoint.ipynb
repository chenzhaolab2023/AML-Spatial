# %% [markdown]
# # Test notebook to verifying cell-cell edge-edge distances

# %%
import numpy as np
import cv2
import tifffile
import pandas as pd
import os
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import math
import seaborn as sns
from skimage import data, segmentation, util, measure
from skimage.segmentation import expand_labels
from numpy import ma 
from matplotlib import ticker, cm 
import scipy.spatial.distance

# %%
# create dictionary of directories for each patient's normalized images
img_dirs = {'P51':'/data/Zhaolab/1_AMLCosMx/Final_scripts/1_Normalization/0_NormalizedImg/P51_R1158_S1_Normalized/', 
            'P52':'/data/Zhaolab/1_AMLCosMx/Final_scripts/1_Normalization/0_NormalizedImg/P52_R1149_S1_Normalized/', 
            'P53':'/data/Zhaolab/1_AMLCosMx/Final_scripts/1_Normalization/0_NormalizedImg/P53_R1149_S2_Normalized/', 
            'P56':'/data/Zhaolab/1_AMLCosMx/Final_scripts/1_Normalization/0_NormalizedImg/P56_R1158_S2_Normalized/', 
            'P57':'/data/Zhaolab/1_AMLCosMx/Final_scripts/1_Normalization/0_NormalizedImg/P57_R1158_S3_Normalized/', 
            'P58':'/data/Zhaolab/1_AMLCosMx/Final_scripts/1_Normalization/0_NormalizedImg/P58_R1149_S3_Normalized/'}

# %%
dist_dir = '/data/Zhaolab/1_AMLCosMx/Final_scripts/5_SpatialAnalysis/1_MeasureCellDists/cell-cell_distances/'

# %%
# create dictionary of patient names
name_dirs = {'p1':'P51', 'p2':'P52', 'p3':'P53', 'p4':'P56', 'p5':'P57', 'p6':'P58'}

# %% [markdown]
# ### One FOV - all cells with touching neighbors

# %%
pt = 'p6'
alt_pt_name = name_dirs[pt]

# define masks location
mask_loc = '/data/Zhaolab/1_AMLCosMx/Final_scripts/2_Segmentation/3_NucMemMerging/' + alt_pt_name + '_hybrid/labels_predicted_2_15_24/'

fov = '02'

# read in table of cell centroid locations
centroid_dir = mask_loc + 'cell_centroids/'
dirlist = os.listdir(centroid_dir)
dirlist.sort()
for item in dirlist:
    if 'F0' + fov in item:
        centroids = pd.read_csv(centroid_dir + item, index_col=0)
        centroids = centroids[['label', 'y', 'x']]
        break

# %%
# get IDs of all cells classified
all_ids = centroids['label'].tolist()

# set cell id as index
one_fov = centroids.set_index('label')

# convert centroid coordinates to numpy array
twoD_array = one_fov[['y','x']].to_numpy()

# calculate pairwise distances between all cell centroids
dists = scipy.spatial.distance.pdist(twoD_array, metric='euclidean')
dists_square = scipy.spatial.distance.squareform(dists, force='no', checks=True)
np.fill_diagonal(dists_square, np.nan, wrap=False) # replace 0s with Nan in diagonal
dists_square = pd.DataFrame(dists_square, index=all_ids, columns=all_ids) # convert to DF

# add DF columns to store nearest neighbor ID and distance
one_fov['centroid_neighbor'] = 0
one_fov['centroid_neighbor_dist'] = 0

for cell in all_ids:
    one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
    one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# Out:
# /tmp/ipykernel_2969332/2040890854.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_2969332/2040890854.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()

# %%
one_fov['centroid_neighbor_dist'].hist(bins=100, range=(0,300))
# Out:
# <AxesSubplot:>

# %%
one_fov['centroid_neighbor_dist'].median() * 0.18
# Out:
# 5.908391236231734

# %%
# read in edge-edge distances computed between all cells
min_dists = pd.read_csv(dist_dir + name_dirs[pt] + '_FOV' + fov + '_cell_contacts.csv', index_col=0)
min_dists.columns = min_dists.columns.astype(int)

# filter to only relevant cells
min_dists = min_dists.filter(items=all_ids, axis=0)
min_dists = min_dists.filter(items=all_ids, axis=1)

one_fov['edge_neighbor'] = 0
one_fov['edge_neighbor_dist'] = 0
one_fov['num_touching'] = 0

for cell in all_ids:
    one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
    nearest_cells = min_dists.loc[cell][min_dists.loc[cell] == min_dists.loc[cell].min()].index.tolist()
            
    if min_dists.loc[cell].min() == 0:
        one_fov['num_touching'].loc[cell] = len(nearest_cells)
                
    if one_fov['centroid_neighbor'].loc[cell] in nearest_cells:
        one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
    else:
        one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# Out:
# /tmp/ipykernel_2969332/2110566002.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_2969332/2110566002.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_2969332/2110566002.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_2969332/2110566002.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]

# %%
one_fov
# Out:
#                  y            x  centroid_neighbor  centroid_neighbor_dist  \
# label
# 1        24.837343   145.286535                 17               47.611826
# 2        23.804947   497.197880               6845               27.593129
# 3        15.434286   529.150476                  4               28.318636
# 4        24.344942   556.030680                  3               28.318636
# 5        17.847182   746.428844                 58               30.625306
# ...            ...          ...                ...                     ...
# 14539  3642.246324  2589.878676               6765               32.572177
# 14540  3642.124277  4211.000000               6759               41.291997
# 14541  3641.941818  4755.229091               6736               66.477084
# 14542  3642.311429   632.957143               6792               21.384946
# 14543  3643.047619  3817.307937               6777               43.002877
#
#        edge_neighbor  edge_neighbor_dist  num_touching
# label
# 1                 17                0.00             2
# 2               6845                0.00             5
# 3                  4                0.00             2
# 4                  3                0.00             3
# 5                 58                0.00             3
# ...              ...                 ...           ...
# 14539           6765                1.00             0
# 14540           6808                0.00             1
# 14541           6736               19.72             0
# 14542           6792                0.00             2
# 14543           6777                9.00             0
#
# [8165 rows x 7 columns]

# %%
one_fov['num_touching'].sort_values(ascending=False)
# Out:
# label
# 4928     15
# 936      12
# 3195     12
# 5397     11
# 1515     11
#          ..
# 1808      0
# 1757      0
# 12454     0
# 1684      0
# 14543     0
# Name: num_touching, Length: 8165, dtype: int64

# %%
dirlist = os.listdir(mask_loc)
dirlist.sort()
for item in dirlist:
    if 'F0' + fov in item:
        masks = tifffile.imread(mask_loc + item)
        break
        
# Load image
img_loc = img_dirs[alt_pt_name]
dirlist = os.listdir(img_loc)
dirlist.sort()

# loop through each FOV for one patient
for file in dirlist:
    if 'F0' + fov in file:
        # Load img
        img = cv2.imread(img_loc + file)

# %%
# select center cell to visualize
ref_cell = 4928

# highlight directly touching cells
viz_masks_neighbors = np.zeros_like(masks, dtype=int)
neighbors = min_dists.loc[ref_cell][min_dists.loc[ref_cell] == 0].index.tolist()
#viz_masks[masks == ref_cell] = 2
for cell in neighbors:
    viz_masks_neighbors[masks == cell] = cell
    
# visualize all neighbor cells in red
boundaries = segmentation.find_boundaries(viz_masks_neighbors, connectivity=1, mode='thick', background=0)
boundaries = boundaries.astype(int)
img[boundaries>0] = [0,0,255]

# visualize center cell in white
viz_masks_ref = np.zeros_like(masks, dtype=int)
viz_masks_ref[masks == ref_cell] = ref_cell
boundaries = segmentation.find_boundaries(viz_masks_ref, connectivity=1, mode='thick', background=0)
boundaries = boundaries.astype(int)
img[boundaries>0] = [255,255,255]

# %%
cv2.imwrite('touchingcell_test.png', img)
# Out:
# True

# %%
# Set the figure size
plt.rcParams["figure.figsize"] = [14, 7]
plt.rcParams["figure.autolayout"] = True

# Random data points
data = np.flipud(viz_masks)

# Plot the data using imshow with gray colormap
plt.imshow(data, cmap='gray')

# Display the plot
plt.show()

# %% [markdown]
# ## Summarize all FOV cell-cell distances

# %%
patients = ['p1', 'p2', 'p3', 'p4', 'p5', 'p6']

# %%
All_fovs = [] # create empty list to store DF objects for each FOV

for pt in patients:

    alt_pt_name = name_dirs[pt]

    # define masks location
    mask_loc = '/data/Zhaolab/1_AMLCosMx/Final_scripts/2_Segmentation/3_NucMemMerging/' + alt_pt_name + '_hybrid/labels_predicted_2_15_24/'
    
    # index through all FOVs
    # read in table of cell centroid locations
    centroid_dir = mask_loc + 'cell_centroids/'
    dirlist = os.listdir(centroid_dir)
    dirlist.sort()
    for item in dirlist:
        
        # get FOV number
        fov = item[34:36]
        
        # read in centroid table, add column specifying FOV number for each cell
        centroids = pd.read_csv(centroid_dir + item, index_col=0)
        centroids = centroids[['label', 'y', 'x']]
        centroids['FOV'] = fov
        
        # get IDs of all cells as list
        all_ids = centroids['label'].tolist()
        
        # set cell id as index
        one_fov = centroids.set_index('label')
        
        # convert centroid coordinates to numpy array
        twoD_array = one_fov[['y','x']].to_numpy()

        # calculate pairwise distances between all cell centroids
        dists = scipy.spatial.distance.pdist(twoD_array, metric='euclidean')
        dists_square = scipy.spatial.distance.squareform(dists, force='no', checks=True)
        np.fill_diagonal(dists_square, np.nan, wrap=False) # replace 0s with Nan in diagonal
        dists_square = pd.DataFrame(dists_square, index=all_ids, columns=all_ids) # convert to DF

        # add DF columns to store nearest neighbor ID and distance in pixels
        one_fov['centroid_neighbor'] = 0
        one_fov['centroid_neighbor_dist'] = 0
        for cell in all_ids:
            one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
            one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
            
        # read in edge-edge distances computed between all cells
        min_dists = pd.read_csv(dist_dir + name_dirs[pt] + '_FOV' + fov + '_cell_contacts.csv', index_col=0)
        min_dists.columns = min_dists.columns.astype(int)

        # filter to only relevant cells
        min_dists = min_dists.filter(items=all_ids, axis=0)
        min_dists = min_dists.filter(items=all_ids, axis=1)

        one_fov['edge_neighbor'] = 0
        one_fov['edge_neighbor_dist'] = 0
        one_fov['num_touching'] = 0

        for cell in all_ids:
            one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
            nearest_cells = min_dists.loc[cell][min_dists.loc[cell] == min_dists.loc[cell].min()].index.tolist()

            if min_dists.loc[cell].min() == 0:
                one_fov['num_touching'].loc[cell] = len(nearest_cells)

            if one_fov['centroid_neighbor'].loc[cell] in nearest_cells:
                one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
            else:
                one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
                
        All_fovs.append(one_fov) # save each FOV DF in list
# Out:
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# ...
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor'].loc[cell] = dists_square.loc[cell].idxmin()
# /tmp/ipykernel_1114521/834660860.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['centroid_neighbor_dist'].loc[cell] = dists_square.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor_dist'].loc[cell] = min_dists.loc[cell].min()
# /tmp/ipykernel_1114521/834660860.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['num_touching'].loc[cell] = len(nearest_cells)
# /tmp/ipykernel_1114521/834660860.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = one_fov['centroid_neighbor'].loc[cell]
# /tmp/ipykernel_1114521/834660860.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_fov['edge_neighbor'].loc[cell] = nearest_cells[0]

# %%
# concatentate all FOVs in single DF
All_fovs_NN = pd.concat(All_fovs)
All_fovs_NN
# Out:
#                  y            x FOV  centroid_neighbor  \
# label
# 1        15.766334    74.070875  01                  2
# 2        14.835116   117.772727  01               1273
# 3        20.265487   218.211898  01               1273
# 4        41.141279   962.670481  01               1275
# 5        16.085487  1059.072565  01               1276
# ...            ...          ...  ..                ...
# 7971   3640.771812  4117.850671  23               3274
# 7972   3641.122563  4992.493036  23               7909
# 7973   3642.707447  3546.191489  23               3278
# 7974   3642.761610  3656.486068  23               3271
# 7975   3642.389439  4786.735974  23               7940
#
#        centroid_neighbor_dist  edge_neighbor  edge_neighbor_dist  num_touching
# label
# 1                   43.711773              2                3.61             0
# 2                   43.545177           1273                0.00             1
# 3                   58.095437           1273                2.24             0
# 4                   31.742707           1275                0.00             2
# 5                   76.697843           1275               38.00             0
# ...                       ...            ...                 ...           ...
# 7971                30.202244           3274                0.00             2
# 7972                55.953195           3248               13.34             0
# 7973                38.458542           3278                0.00             1
# 7974                23.990679           3271                0.00             3
# 7975                25.726145           7940                0.00             1
#
# [630206 rows x 8 columns]

# %%
import matplotlib as mpl
mpl.rc('font',family='Arial')

# %%
# covert dataframe column to numpy array
data = All_fovs_NN['num_touching'].to_numpy()

fig = plt.figure(dpi=600)
ax = fig.add_subplot(1,1,1)

# define bins
d = np.diff(np.unique(data)).min()
left_of_first_bin = data.min() - float(d)/2
right_of_last_bin = data.max() + float(d)/2
bins = list(range(0, All_fovs_NN['num_touching'].max() + 1))

# create histogram
ax.hist(data, np.arange(left_of_first_bin, right_of_last_bin + d, d), color = "skyblue", edgecolor = "black")
ax.xaxis.set_ticks(np.arange(0, 16, 1)) # specify x-axis ticks
ax.set_xlabel('Number of directly touching cell neighbors')
ax.set_ylabel('Cell count')
plt.axvline(x = 0.5, color = 'black', linestyle='dashed')
fig.savefig('cell_contacts_histogram.png', bbox_inches="tight")

# %%
# covert dataframe column to numpy array
data = All_fovs_NN['num_touching'].to_numpy()

# create subplot object to make plot
fig, ax = plt.subplots(1, 1, tight_layout=True, figsize=(10,6))

# define bins
d = np.diff(np.unique(data)).min()
left_of_first_bin = data.min() - float(d)/2
right_of_last_bin = data.max() + float(d)/2
bins = list(range(0, All_fovs_NN['num_touching'].max() + 1))

# create histogram
ax.hist(data, np.arange(left_of_first_bin, right_of_last_bin + d, d), color = "skyblue", edgecolor = "black", log=True)
ax.xaxis.set_ticks(np.arange(0, 16, 1)) # specify x-axis ticks
ax.set_xlabel('Number of directly touching cell neighbors')
ax.set_ylabel('Cell count')
plt.show()
